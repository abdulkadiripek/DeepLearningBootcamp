# %%
import torch

# %%
torch.cuda.is_available() # for nvidia gpu
# Out:
# True

# %%
torch.backends.mps.is_available() # for macbook
# Out:
# False

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
device
# Out:
# 'cuda'

# %%
tensor = torch.tensor([1,2,3])

# %%
tensor
# Out:
# tensor([1, 2, 3])

# %%
tensor.device
# Out:
# device(type='cpu')

# %%
#manual

# %%
tensor_device = tensor.to(device)

# %%
tensor_device
# Out:
# tensor([1, 2, 3], device='cuda:0')

# %%
tensor.numpy()
# Out:
# array([1, 2, 3])

# %%
# tensor_device.numpy()  # tensor gpu'da numpy cpu da, uyumsuzlar.

# %%
tensor_device.cpu() # geri cpu'ya alıyoruz.
# Out:
# tensor([1, 2, 3])

# %%
# context manager

# %%
with torch.device(device):
    tensor2 = torch.tensor([1,2,3])
    layer = torch.nn.Linear(20,30)

# %%
tensor2.device
# Out:
# device(type='cuda', index=0)

# %%
layer.weight.device
# Out:
# device(type='cuda', index=0)

# %%
# torch.set_default_device

# %%
device
# Out:
# 'cuda'

# %%
torch.set_default_device(device)

# %%
tensor4 = torch.tensor([1,2,3])
print(tensor4.device)
layer4 = torch.nn.Linear(10,20)
print(layer4.weight.device)
# Out:
# cuda:0
# cuda:0

# %%
tensor_device = torch.tensor([1,2,3],device="cuda")

# %%
tensor_device.device
# Out:
# device(type='cuda', index=0)
