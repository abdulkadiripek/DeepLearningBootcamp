# %%
yas = 20

if yas < 18:
    print("18 yaşından küçüksünüz")
elif yas >= 18 and yas < 30:
    print("18 ile 30 yaş arasında bir gençsiniz")
elif yas >= 30 and yas < 40:
    print("30 ve 40 arasına gelmişsiniz")
else:
    print("40 yaşından daha büyüksünüz")
# Out:
# 18 ile 30 yaş arasında bir gençsiniz

# %%
my_dictionary = {"k1":10,"k2k":"a","k32":30,"k4":"c"}

# %%
for i,j in my_dictionary.items():
    if j == "c":
        print("Evet")
# Out:
# Evet

# %%
my_other_dictionary = {"b":203,"c":"a","a":400,"d":"f"}
for i,j in my_other_dictionary.items():
    if i == "a":
        print(True)
# Out:
# True

# %%
my_numbers = [1,2,3,4,5,6,19,20,32,21,20,1111,23,24]
a = 0
for i in my_numbers:
    if i%2 == 0:
        print(i)
# Out:
# 2
# 4
# 6
# 20
# 32
# 20
# 24

# %%
r_list = [3,2,5,8,4,6,9,12]
pi = 3.14
my_new_list = list()
for i in r_list:
    my_new_list.append(pi*i*2)
print(my_new_list)
# Out:
# [18.84, 12.56, 31.400000000000002, 50.24, 25.12, 37.68, 56.52, 75.36]

# %%
age_name_list = [("Ahmet",30),("Ayse",24),("Mehmet",40),("Fatma",29)]
my_new_age_list = list()
for i in range(len(age_name_list)):
    my_new_age_list.append(age_name_list[i][1]) 
my_new_age_list
# Out:
# [30, 24, 40, 29]

# %%
from random import randint
metal_list = ["Metallica","Iron Maiden","Dream Theater","Megadeth","AC/DC"]
metal_list[randint(0,len(metal_list)-1)]
# Out:
# 'Iron Maiden'
