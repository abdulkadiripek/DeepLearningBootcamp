# %%
def myFunc(num):
    return num ** 3

myList = [2,3,4,5,6]
my_new_dizi = []
for i in myList:
    my_new_dizi.append(myFunc(i))
my_new_dizi
# Out:
# [8, 27, 64, 125, 216]

# %%
barkodDizisi = ["ABC231","SA3123XYZ","XYZA123Q","QRE1231KJ","X112QGL"]
list(filter(lambda string : "XYZ" in string,barkodDizisi))
# Out:
# ['SA3123XYZ', 'XYZA123Q']
