# %%
import numpy as np

# %%
new_array = np.random.randint(1,100,20)
new_array
# Out:
# array([35, 88, 71, 21, 29, 16, 76,  5, 80, 64, 45, 60, 44, 99, 11, 18,  6,
#        17, 73, 72])

# %%
new_array[new_array>40]
# Out:
# array([88, 71, 76, 80, 64, 45, 60, 44, 99, 73, 72])

# %%
# transpose & reshape

# %%
matrix_array = np.array([[10,20,30],[45,55,65]])
matrix_array.shape
# Out:
# (2, 3)

# %%
matrix_array
# Out:
# array([[10, 20, 30],
#        [45, 55, 65]])

# %%
matrix_array.transpose() # 2,3 olan shape'i 3,2 olarak değiştirir. Transpozunu alır.
# Out:
# array([[10, 45],
#        [20, 55],
#        [30, 65]])

# %%
random_array = np.random.random((1,6))
random_array
# Out:
# array([[0.87802099, 0.52595212, 0.9040436 , 0.39497735, 0.31954686,
#         0.33916073]])

# %%
random_array.reshape(3,2) # Dizimizin shape'ini yeniden şekillendirir.
# Out:
# array([[0.87802099, 0.52595212],
#        [0.9040436 , 0.39497735],
#        [0.31954686, 0.33916073]])
